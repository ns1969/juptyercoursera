# %%
# # My Jupyter Notebook on IBM Watson Studio

# **Nikhil Sharma**

# Student

# *I am interested in data science because I love to play with data*

# ### The code multiplies two numbers

# %%
a=int(input('enter number 1'))
b=int(input('Enter number 2'))
print(a*b)
# Out:
# enter number 12
# Enter number 231231
# 62462

# %%
[projectlink](https://www.example.com)
1. hey
2. hh
3. eef

- jds
- dsa
- dsa
